# %%
import seaborn as sns
sns.set(style="darkgrid")
import geopandas as gpd
from shapely.geometry import Point

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import glob
import numpy as np

# %%
#fig, axes = plt.subplots(figsize=(9,6))
files = glob.glob("/home/joao/Documentos/21032023_repetições/21032023/*.csv")

df = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df = pd.concat([plt,df], ignore_index=False)
#    df = df.loc[(df['VehId'] == 2) | (df['VehId'] == 5) | (df['VehId'] == 7) | (df['VehId'] == 8) | (df['VehId'] == 12) | 
#               (df['VehId'] == 108) | (df['VehId'] == 110) | (df['VehId'] == 115) | (df['VehId'] == 116) | (df['VehId'] == 119)]
#    df = df.loc[(df['VehId'] == 8)]
#    df = df.loc[(df['VehId'] < 20)]


#df_final=pd.DataFrame()

#fig, axes = plt.subplots(figsize=(9,6))
files = glob.glob("/home/joao/Documentos/21032023_repetições/pontos/*.csv")

df_final = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df_final = pd.concat([plt,df_final], ignore_index=False)
#    df_final['repetições'] = df.groupby(['grid_origem','grid_destino']).size().reset_index().groupby(['grid_origem','grid_destino']).sum()

#df['repetições'].nlargest(5)

df_final
# Out:
#      Unnamed: 0  VehId_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 0             0      372   354  Origem  Destino        65321         78354
# 1             1      372   357  Origem  Destino        51163         59486
# 2             2      372   360  Origem  Destino        64034         63154
# 3             3      372   363  Origem  Destino        50335         58233
# 4             4      372   368  Origem  Destino        49956         45426
# ..          ...      ...   ...     ...      ...          ...           ...
# 151         151      282  1892  Origem  Destino        45813         47054
# 0             0      325  1809  Origem  Destino        51978         46180
# 1             1      325  3134  Origem  Destino        34023         30422
# 2             2      325  3281  Origem  Destino        68170         51163
# 3             3      325  3690  Origem  Destino        20542         65652
#
#          lon_x      lat_x      lon_y      lat_y
# ...

# %%
resultados=pd.DataFrame()

resultados['repetições'] = df_final.groupby(['VehId_x','grid_origem','grid_destino']).size().reset_index().groupby(['VehId_x','grid_origem','grid_destino']).sum()

df_final.shape
# Out:
# (32552, 11)

# %%
#resultados = resultados.reset_index()

resultados
# Out:
#                                   repetições
# VehId_x grid_origem grid_destino
# 2       35232       76279                  1
#         50386       51164                  1
#         50754       63615                  1
#                     64034                  2
#         51163       50385                  1
# ...                                      ...
# 624     76704       64463                  1
#         78354       49925                  1
# 625     77130       64463                  1
#         78322       69926                  1
# 630     64034       58992                  1
#
# [25476 rows x 1 columns]

# %%
res = pd.DataFrame()
for i in resultados:
    res = resultados.drop(resultados[resultados['repetições'] < 5].index)
res
# Out:
#                                   repetições
# VehId_x grid_origem grid_destino
# 10      57359       42976                  5
# 11      62804       58235                  5
# 12      48208       64033                  6
#         64033       48209                  6
# 128     20542       29718                  5
# ...                                      ...
# 608     20542       21655                  6
#         29719       26212                  5
# 609     78321       50738                  6
#         78355       48705                  6
# 610     21285       63984                  5
#
# [424 rows x 1 columns]

# %%
res = res.reset_index()

res
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 0         10        57359         42976           5
# 1         11        62804         58235           5
# 2         12        48208         64033           6
# 3         12        64033         48209           6
# 4        128        20542         29718           5
# ..       ...          ...           ...         ...
# 419      608        20542         21655           6
# 420      608        29719         26212           5
# 421      609        78321         50738           6
# 422      609        78355         48705           6
# 423      610        21285         63984           5
#
# [424 rows x 4 columns]

# %%
table = pd.DataFrame()

table['duplicados'] = res.pivot_table(columns=['VehId_x'], aggfunc='size')

print(table)
# Out:
#          duplicados
# VehId_x
# 10                1
# 11                1
# 12                2
# 128               1
# 130               1
# ...             ...
# 599               1
# 607               1
# 608               2
# 609               2
# 610               1
#
# [145 rows x 1 columns]

# %%
table[table['duplicados'] >= 10]
# Out:
#          duplicados
# VehId_x
# 276              15
# 371              10
# 388              12
# 450              13
# 550              15
# 560              12
# 561              11

# %%
res[res['VehId_x'] == 276]
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 91       276        64462         76704           5
# 92       276        74544         77129          14
# 93       276        74545         75866           5
# 94       276        74548         77129          10
# 95       276        75867         74546           8
# 96       276        76292         74544           8
# 97       276        76292         74545          15
# 98       276        76292         74546          12
# 99       276        76292         74549          10
# 100      276        76705         64463           5
# 101      276        76705         74544           7
# 102      276        77130         74544           5
# 103      276        77130         74545          11
# 104      276        77130         74546           9
# 105      276        77130         74549           5

# %%
res[res['VehId_x'] == 371]
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 171      371        51163         78354          11
# 172      371        57358         78354           7
# 173      371        75363         51972          10
# 174      371        75364         50746           7
# 175      371        75364         51972          17
# 176      371        75364         51978           5
# 177      371        78354         51574           7
# 178      371        78354         64044           6
# 179      371        78354         75364           8
# 180      371        78354         78354          15

# %%
res[res['VehId_x'] == 388]
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 190      388        39692         66030           9
# 191      388        45813         66030          24
# 192      388        48204         66030           8
# 193      388        52334         66030           6
# 194      388        66449         37267          17
# 195      388        66449         38478          10
# 196      388        66449         38479          14
# 197      388        66449         40098          22
# 198      388        66449         45002           5
# 199      388        66449         45817          10
# 200      388        66449         75312          10
# 201      388        75312         66449           9

# %%
res[res['VehId_x'] == 450]
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 240      450        64044         74563           5
# 241      450        64462         74563           5
# 242      450        66520         74563           6
# 243      450        69505         74563           5
# 244      450        69900         74563           5
# 245      450        74155         74563          13
# 246      450        74155         74987           7
# 247      450        74551         74563          10
# 248      450        74555         74563           7
# 249      450        74556         74563          13
# 250      450        74556         74987           5
# 251      450        74987         74987          86
# 252      450        74988         74987           7

# %%
res[res['VehId_x'] == 550]
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 332      550        64033         71591           8
# 333      550        64034         71591          13
# 334      550        64034         76704           6
# 335      550        64034         78354          12
# 336      550        71169         64033           7
# 337      550        71169         64034           5
# 338      550        71592         64033           5
# 339      550        74544         78354           5
# 340      550        74548         78354          11
# 341      550        74550         78354           6
# 342      550        77130         74556           6
# 343      550        77130         74557           5
# 344      550        78354         74545           5
# 345      550        78354         74547           7
# 346      550        78354         74550          20

# %%
res[res['VehId_x'] == 560]
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 350      560        45825         78354           6
# 351      560        78354         44602           6
# 352      560        78354         45009           6
# 353      560        78354         45012           9
# 354      560        78354         45013           9
# 355      560        78354         45422           6
# 356      560        78354         47466          14
# 357      560        78354         77480           6
# 358      560        78354         77896           8
# 359      560        78354         77928          36
# 360      560        78354         78321           6
# 361      560        78354         78354          91

# %%
res[res['VehId_x'] == 561]
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 362      561        21933         28551           8
# 363      561        47449         48204           8
# 364      561        47451         48204          11
# 365      561        47451         48205           6
# 366      561        47868         48204          15
# 367      561        47868         48205           5
# 368      561        47869         48204           5
# 369      561        48204         48284           5
# 370      561        66449         50738          44
# 371      561        66449         51147           9
# 372      561        66449         51558          11

# %% [markdown]
# ## Veículo 276: grids diferentes e o mesmo veículo

# %%
vei276 = res[res['VehId_x'] == 276]

vei276
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 91       276        64462         76704           5
# 92       276        74544         77129          14
# 93       276        74545         75866           5
# 94       276        74548         77129          10
# 95       276        75867         74546           8
# 96       276        76292         74544           8
# 97       276        76292         74545          15
# 98       276        76292         74546          12
# 99       276        76292         74549          10
# 100      276        76705         64463           5
# 101      276        76705         74544           7
# 102      276        77130         74544           5
# 103      276        77130         74545          11
# 104      276        77130         74546           9
# 105      276        77130         74549           5

# %%
df_trip276 = df_final.merge(vei276, how='inner', on=['grid_origem','grid_destino'])

df_trip276
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 0            18        397   830  Origem  Destino        76705         64463
# 1            78        366  1957  Origem  Destino        76705         64463
# 2            27        185  1625  Origem  Destino        76705         64463
# 3            93        185  2141  Origem  Destino        76705         64463
# 4            10        463   540  Origem  Destino        76705         64463
# ..          ...        ...   ...     ...      ...          ...           ...
# 188          65        276  1194  Origem  Destino        77130         74544
# 189          70        276  1216  Origem  Destino        77130         74544
# 190          75        276  1242  Origem  Destino        77130         74544
# 191         171        276  1968  Origem  Destino        77130         74544
# 192         208        276  2588  Origem  Destino        77130         74544
#
# ...

# %%
#df_trip276 = df_trip276.drop_duplicates(subset=['grid_origem','grid_destino'])

#df_trip276

# %%
df = pd.read_csv('/home/joao/Documentos/21032023_repetições/21032023/repetições_vei276.csv')

df
# Out:
#     Unnamed: 0  grid_origem  grid_destino  repetições
# 0            0        29711         20908           1
# 1            1        34048         76279           1
# 2            2        36442         76704           1
# 3            3        36472         48204           1
# 4            4        38478         76704           1
# ..         ...          ...           ...         ...
# 85          85        77130         74546           9
# 86          86        77130         74547           4
# 87          87        77130         74549           5
# 88          88        77130         77130           1
# 89          89        78322         76704           1
#
# [90 rows x 4 columns]

# %%
df['repetições'].max()
# Out:
# 15

# %%
df_trip276 = df_trip276[(df_trip276['repetições'] == df_trip276['repetições'].max()) & (df_trip276['grid_origem'] != df_trip276['grid_destino']) &
                       (df_trip276['VehId_x_x'] == df_trip276['VehId_x_y'])]

# %%
df_trip276
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 120          15        276   936  Origem  Destino        76292         74545
# 121          63        276  1152  Origem  Destino        76292         74545
# 122          66        276  1196  Origem  Destino        76292         74545
# 123          76        276  1244  Origem  Destino        76292         74545
# 124          82        276  1263  Origem  Destino        76292         74545
# 125          99        276  1347  Origem  Destino        76292         74545
# 126         104        276  1371  Origem  Destino        76292         74545
# 127         116        276  1424  Origem  Destino        76292         74545
# 128         120        276  1440  Origem  Destino        76292         74545
# 129         135        276  1499  Origem  Destino        76292         74545
# 130         139        276  1516  Origem  Destino        76292         74545
# ...

# %%
df_trip276['Trip'].unique()
# Out:
# array([ 936, 1152, 1196, 1244, 1263, 1347, 1371, 1424, 1440, 1499, 1516,
#        1586, 1640, 2086, 2341])

# %% [markdown]
# ## Veículo 371: grids diferentes e o mesmo veículo

# %%
vei371 = res[res['VehId_x'] == 371]

vei371
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 171      371        51163         78354          11
# 172      371        57358         78354           7
# 173      371        75363         51972          10
# 174      371        75364         50746           7
# 175      371        75364         51972          17
# 176      371        75364         51978           5
# 177      371        78354         51574           7
# 178      371        78354         64044           6
# 179      371        78354         75364           8
# 180      371        78354         78354          15

# %%
df_trip371 = df_final.merge(vei371, how='inner', on=['grid_origem','grid_destino'])

df_trip371
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 0            41        154  1570  Origem  Destino        78354         64044
# 1            28        304   992  Origem  Destino        78354         64044
# 2            50        304  1532  Origem  Destino        78354         64044
# 3            57        304  1679  Origem  Destino        78354         64044
# 4            64        304  1815  Origem  Destino        78354         64044
# ..          ...        ...   ...     ...      ...          ...           ...
# 334         237        371  3144  Origem  Destino        75363         51972
# 335         283        371  3508  Origem  Destino        75363         51972
# 336         297        371  3741  Origem  Destino        75363         51972
# 337         313        371  3865  Origem  Destino        75363         51972
# 338         323        371  3927  Origem  Destino        75363         51972
#
# ...

# %%
df_trip371 = df_trip371[(df_trip371['repetições'] == df_trip371['repetições'].max()) & (df_trip371['grid_origem'] != df_trip371['grid_destino']) &
                       (df_trip371['VehId_x_x'] == df_trip371['VehId_x_y'])]

df_trip371
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 265           7        371  1336  Origem  Destino        75364         51972
# 266          33        371  1519  Origem  Destino        75364         51972
# 267          35        371  1530  Origem  Destino        75364         51972
# 268          40        371  1569  Origem  Destino        75364         51972
# 269          46        371  1624  Origem  Destino        75364         51972
# 270          78        371  1882  Origem  Destino        75364         51972
# 271         107        371  2121  Origem  Destino        75364         51972
# 272         114        371  2171  Origem  Destino        75364         51972
# 273         121        371  2227  Origem  Destino        75364         51972
# 274         156        371  2531  Origem  Destino        75364         51972
# 275         173        371  2642  Origem  Destino        75364         51972
# ...

# %%
df_trip371['Trip'].unique()
# Out:
# array([1336, 1519, 1530, 1569, 1624, 1882, 2121, 2171, 2227, 2531, 2642,
#        2646, 3085, 3750, 3798, 3909, 4395])

# %% [markdown]
# ## Veículo 388: grids diferentes e o mesmo veículo

# %%
vei388 = res[res['VehId_x'] == 388]

vei388
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 190      388        39692         66030           9
# 191      388        45813         66030          24
# 192      388        48204         66030           8
# 193      388        52334         66030           6
# 194      388        66449         37267          17
# 195      388        66449         38478          10
# 196      388        66449         38479          14
# 197      388        66449         40098          22
# 198      388        66449         45002           5
# 199      388        66449         45817          10
# 200      388        66449         75312          10
# 201      388        75312         66449           9

# %%
df_trip388 = df_final.merge(vei388, how='inner', on=['grid_origem','grid_destino'])

df_trip388
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 0            67        304  1829  Origem  Destino        48204         66030
# 1             0        574   143  Origem  Destino        48204         66030
# 2           130        574  1036  Origem  Destino        48204         66030
# 3             6        535   455  Origem  Destino        48204         66030
# 4            39        535   990  Origem  Destino        48204         66030
# ..          ...        ...   ...     ...      ...          ...           ...
# 355         153        388  1185  Origem  Destino        66449         45002
# 356         277        388  1801  Origem  Destino        66449         45002
# 357         282        388  1811  Origem  Destino        66449         45002
# 358         283        388  1816  Origem  Destino        66449         45002
# 359         290        388  1837  Origem  Destino        66449         45002
#
# ...

# %%
df_trip388 = df_trip388[(df_trip388['repetições'] == df_trip388['repetições'].max()) & (df_trip388['grid_origem'] != df_trip388['grid_destino']) &
                       (df_trip388['VehId_x_x'] == df_trip388['VehId_x_y'])]

df_trip388
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 316          42        388   818  Origem  Destino        45813         66030
# 317          65        388   907  Origem  Destino        45813         66030
# 318         138        388  1140  Origem  Destino        45813         66030
# 319         140        388  1144  Origem  Destino        45813         66030
# 320         154        388  1190  Origem  Destino        45813         66030
# 321         155        388  1196  Origem  Destino        45813         66030
# 322         160        388  1224  Origem  Destino        45813         66030
# 323         198        388  1428  Origem  Destino        45813         66030
# 324         201        388  1438  Origem  Destino        45813         66030
# 325         222        388  1551  Origem  Destino        45813         66030
# 326         247        388  1665  Origem  Destino        45813         66030
# ...

# %%
df_trip388['Trip'].unique()
# Out:
# array([ 818,  907, 1140, 1144, 1190, 1196, 1224, 1428, 1438, 1551, 1665,
#        1803, 1806, 1867, 1879, 1912, 1918, 1940, 1976, 2003, 2096, 2120,
#        2135, 2180])

# %% [markdown]
# ## Teste com o veículo 276 para o QGIS

# %%
import pandas as pd
import glob
import numpy as np
files = glob.glob("/media/joao/Seagate Expansion Drive 09032021/22122022/ved_descompactados/*.csv")

df = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df = pd.concat([plt,df], ignore_index=False)
    df = df.loc[(df['VehId'] == 276)]

df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 14484   372.897793    276  2685              0      42.309357      -83.677397
# 14485   372.897793    276  2685           1000      42.309357      -83.677397
# 14486   372.897793    276  2685           1900      42.309357      -83.677397
# 14487   372.897793    276  2685           2100      42.309357      -83.677397
# 14488   372.897793    276  2685           2900      42.309357      -83.677397
# ...            ...    ...   ...            ...            ...             ...
# 351125  132.914868    276  1437         309400      42.298058      -83.719643
# 351126  132.914868    276  1437         310000      42.297975      -83.719941
# 351127  132.914868    276  1437         311300      42.297975      -83.719941
# 351128  132.914868    276  1437         311900      42.297975      -83.719941
# 351129  132.914868    276  1437         312900      42.297975      -83.719941
#
# ...

# %%
df = df.sort_values(by=['Trip','Timestamp(ms)'])


df
# Out:
#            DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 98979    2.550748    276   882              0      42.317741      -83.679196
# 98980    2.550748    276   882           1000      42.317741      -83.679196
# 98981    2.550748    276   882           2100      42.317741      -83.679196
# 98982    2.550748    276   882           3300      42.317741      -83.679196
# 98983    2.550748    276   882           4400      42.317741      -83.679196
# ...           ...    ...   ...            ...            ...             ...
# 50555  373.520700    276  2688         137000      42.309137      -83.677300
# 50556  373.520700    276  2688         137100      42.309137      -83.677300
# 50557  373.520700    276  2688         138000      42.309137      -83.677300
# 50558  373.520700    276  2688         138100      42.309137      -83.677300
# 50559  373.520700    276  2688         139200      42.309137      -83.677300
#
# ...

# %%
#df = df.sort_values(by='DayNum')

df['datetime'] = pd.to_datetime(df['DayNum'], unit='D', origin=pd.Timestamp('2017-11-01'))


print(df['datetime'].min())

print(df['datetime'].max())


print(df['DayNum'].min())

print(df['DayNum'].max())

print(df.shape)
# Out:
# 2017-11-03 13:13:04.625600
# 2018-11-09 12:29:48.519225600
# 2.55074798148
# 373.520700454
# (75604, 23)

# %%
t = pd.DataFrame()

t = pd.date_range(start='2017-11-03 13:13:04.625600', end='2018-11-09 12:29:48.519225600', periods=75604)


df['datetime'] = t

df.datetime
# Out:
# 98979   2017-11-03 13:13:04.625600000
# 98980   2017-11-03 13:20:08.574436602
# 98981   2017-11-03 13:27:12.523273204
# 98982   2017-11-03 13:34:16.472109806
# 98983   2017-11-03 13:41:20.420946408
#                      ...
# 50555   2018-11-09 12:01:32.723879192
# 50556   2018-11-09 12:08:36.672715796
# 50557   2018-11-09 12:15:40.621552396
# 50558   2018-11-09 12:22:44.570389000
# 50559   2018-11-09 12:29:48.519225600
# Name: datetime, Length: 75604, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df['datetime']).round('s')

df.datetime
# Out:
# 98979   2017-11-03 13:13:05
# 98980   2017-11-03 13:20:09
# 98981   2017-11-03 13:27:13
# 98982   2017-11-03 13:34:16
# 98983   2017-11-03 13:41:20
#                 ...
# 50555   2018-11-09 12:01:33
# 50556   2018-11-09 12:08:37
# 50557   2018-11-09 12:15:41
# 50558   2018-11-09 12:22:45
# 50559   2018-11-09 12:29:49
# Name: datetime, Length: 75604, dtype: datetime64[ns]

# %%
df.to_csv('veiculo276.csv')

# %% [markdown]
# ## Teste com o veículo 371 para o QGIS

# %%
import pandas as pd
import glob
import numpy as np
files = glob.glob("/media/joao/Seagate Expansion Drive 09032021/22122022/ved_descompactados/*.csv")

df = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df = pd.concat([plt,df], ignore_index=False)
    df = df.loc[(df['VehId'] == 371)]

df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 19877   372.459839    371  4395              0      42.264828      -83.680335
# 19878   372.459839    371  4395            500      42.264828      -83.680335
# 19879   372.459839    371  4395           1500      42.264828      -83.680335
# 19880   372.459839    371  4395           2300      42.264828      -83.680335
# 19881   372.459839    371  4395           2500      42.264828      -83.680335
# ...            ...    ...   ...            ...            ...             ...
# 356211  132.670756    371  2301         704800      42.283644      -83.745879
# 356212  132.670756    371  2301         705000      42.283462      -83.745879
# 356213  132.670756    371  2301         705500      42.283462      -83.745879
# 356214  132.670756    371  2301         706600      42.283462      -83.745879
# 356215  132.670756    371  2301         707600      42.283462      -83.745879
#
# ...

# %%
df = df.sort_values(by=['Trip','Timestamp(ms)'])


df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 338822    5.560242    371  1288              0      42.277653      -83.753771
# 338823    5.560242    371  1288            600      42.277653      -83.753771
# 338824    5.560242    371  1288            700      42.277653      -83.753771
# 338825    5.560242    371  1288           1700      42.277653      -83.753771
# 338826    5.560242    371  1288           2700      42.277653      -83.753771
# ...            ...    ...   ...            ...            ...             ...
# 21194   372.863264    371  4411         644900      42.282303      -83.734510
# 21195   372.863264    371  4411         645100      42.282303      -83.734510
# 21196   372.863264    371  4411         645700      42.282303      -83.734510
# 21197   372.863264    371  4411         646200      42.282303      -83.734510
# 21198   372.863264    371  4411         647200      42.282303      -83.734510
#
# ...

# %%
#df = df.sort_values(by='DayNum')

df['datetime'] = pd.to_datetime(df['DayNum'], unit='D', origin=pd.Timestamp('2017-11-01'))


print(df['datetime'].min())

print(df['datetime'].max())


print(df['DayNum'].min())

print(df['DayNum'].max())

print(df.shape)
# Out:
# 2017-11-06 13:26:44.941600
# 2018-11-08 20:43:06.028780800
# 5.56024237963
# 372.863264222
# (351393, 23)

# %%
t = pd.DataFrame()

t = pd.date_range(start='2017-11-06 13:26:44.941600', end='2018-11-08 20:43:06.028780800', periods=351393)


df['datetime'] = t

df.datetime
# Out:
# 338822   2017-11-06 13:26:44.941600000
# 338823   2017-11-06 13:28:15.253790053
# 338824   2017-11-06 13:29:45.565980106
# 338825   2017-11-06 13:31:15.878170159
# 338826   2017-11-06 13:32:46.190360212
#                       ...
# 21194    2018-11-08 20:37:04.780020584
# 21195    2018-11-08 20:38:35.092210640
# 21196    2018-11-08 20:40:05.404400692
# 21197    2018-11-08 20:41:35.716590744
# 21198    2018-11-08 20:43:06.028780800
# Name: datetime, Length: 351393, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df['datetime']).round('s')

df.datetime
# Out:
# 338822   2017-11-06 13:26:45
# 338823   2017-11-06 13:28:15
# 338824   2017-11-06 13:29:46
# 338825   2017-11-06 13:31:16
# 338826   2017-11-06 13:32:46
#                  ...
# 21194    2018-11-08 20:37:05
# 21195    2018-11-08 20:38:35
# 21196    2018-11-08 20:40:05
# 21197    2018-11-08 20:41:36
# 21198    2018-11-08 20:43:06
# Name: datetime, Length: 351393, dtype: datetime64[ns]

# %%
df.to_csv('veiculo371.csv')

# %% [markdown]
# ## Teste com o veículo 388 para o QGIS

# %%
import pandas as pd
import glob
import numpy as np
files = glob.glob("/media/joao/Seagate Expansion Drive 09032021/22122022/ved_descompactados/*.csv")

df = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df = pd.concat([plt,df], ignore_index=False)
    df = df.loc[(df['VehId'] == 388)]

df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 22180   372.519384    388  2175              0      42.230295      -83.699780
# 22181   372.519384    388  2175            300      42.230295      -83.699780
# 22182   372.519384    388  2175            600      42.230295      -83.699780
# 22183   372.519384    388  2175            700      42.230295      -83.699780
# 22184   372.519384    388  2175           1300      42.230295      -83.699780
# ...            ...    ...   ...            ...            ...             ...
# 358268  132.865674    388  1131         334300      42.230399      -83.699277
# 358269  132.865674    388  1131         334400      42.230399      -83.699277
# 358270  132.865674    388  1131         335400      42.230399      -83.699277
# 358271  132.865674    388  1131         336400      42.230399      -83.699277
# 358272  132.865674    388  1131         337500      42.230399      -83.699277
#
# ...

# %%
df = df.sort_values(by=['Trip','Timestamp(ms)'])


df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 39079     1.579761    388   636              0      42.263847      -83.757950
# 39080     1.579761    388   636           8500      42.263847      -83.757950
# 39081     1.579761    388   636          13600      42.263847      -83.757950
# 39082     1.579761    388   636          19600      42.263847      -83.757950
# 39083     1.579761    388   636          24600      42.263847      -83.757950
# ...            ...    ...   ...            ...            ...             ...
# 102457  374.535685    388  2183         597000      42.279597      -83.750287
# 102458  374.535685    388  2183         598000      42.279594      -83.750047
# 102459  374.535685    388  2183         599000      42.279594      -83.750047
# 102460  374.535685    388  2183         599800      42.279594      -83.750047
# 102461  374.535685    388  2183         600100      42.279594      -83.750047
#
# ...

# %%
#df = df.sort_values(by='DayNum')

df['datetime'] = pd.to_datetime(df['DayNum'], unit='D', origin=pd.Timestamp('2017-11-01'))


print(df['datetime'].min())

print(df['datetime'].max())


print(df['DayNum'].min())

print(df['DayNum'].max())

print(df.shape)
# Out:
# 2017-11-02 13:54:51.361600
# 2018-11-10 12:51:23.212771328
# 1.57976112963
# 374.535685333
# (331418, 23)

# %%
t = pd.DataFrame()

t = pd.date_range(start='2017-11-02 13:54:51.361600', end='2018-11-10 12:51:23.212771328', periods=331418)


df['datetime'] = t

df.datetime
# Out:
# 39079    2017-11-02 13:54:51.361600000
# 39080    2017-11-02 13:56:28.590745913
# 39081    2017-11-02 13:58:05.819891826
# 39082    2017-11-02 13:59:43.049037740
# 39083    2017-11-02 14:01:20.278183653
#                       ...
# 102457   2018-11-10 12:44:54.296187676
# 102458   2018-11-10 12:46:31.525333588
# 102459   2018-11-10 12:48:08.754479500
# 102460   2018-11-10 12:49:45.983625416
# 102461   2018-11-10 12:51:23.212771328
# Name: datetime, Length: 331418, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df['datetime']).round('s')

df.datetime
# Out:
# 39079    2017-11-02 13:54:51
# 39080    2017-11-02 13:56:29
# 39081    2017-11-02 13:58:06
# 39082    2017-11-02 13:59:43
# 39083    2017-11-02 14:01:20
#                  ...
# 102457   2018-11-10 12:44:54
# 102458   2018-11-10 12:46:32
# 102459   2018-11-10 12:48:09
# 102460   2018-11-10 12:49:46
# 102461   2018-11-10 12:51:23
# Name: datetime, Length: 331418, dtype: datetime64[ns]

# %%
df.to_csv('veiculo388.csv')

# %% [markdown]
# ## Veículo 450: grids que podem ser iguais e o mesmo veículo

# %%
vei450 = res[res['VehId_x'] == 450]

vei450
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 240      450        64044         74563           5
# 241      450        64462         74563           5
# 242      450        66520         74563           6
# 243      450        69505         74563           5
# 244      450        69900         74563           5
# 245      450        74155         74563          13
# 246      450        74155         74987           7
# 247      450        74551         74563          10
# 248      450        74555         74563           7
# 249      450        74556         74563          13
# 250      450        74556         74987           5
# 251      450        74987         74987          86
# 252      450        74988         74987           7

# %% [markdown]
# ### Eliminação do valor máximo com os grids repetidos

# %%
vei450 = vei450.drop(vei450[vei450['repetições'] == 86].index)

vei450
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 240      450        64044         74563           5
# 241      450        64462         74563           5
# 242      450        66520         74563           6
# 243      450        69505         74563           5
# 244      450        69900         74563           5
# 245      450        74155         74563          13
# 246      450        74155         74987           7
# 247      450        74551         74563          10
# 248      450        74555         74563           7
# 249      450        74556         74563          13
# 250      450        74556         74987           5
# 252      450        74988         74987           7

# %%
df_trip450 = df_final.merge(vei450, how='inner', on=['grid_origem','grid_destino'])

df_trip450
# Out:
#     Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 0            5        450   813  Origem  Destino        74556         74563
# 1           43        450   966  Origem  Destino        74556         74563
# 2           47        450   987  Origem  Destino        74556         74563
# 3           56        450  1021  Origem  Destino        74556         74563
# 4           64        450  1064  Origem  Destino        74556         74563
# ..         ...        ...   ...     ...      ...          ...           ...
# 95         361        450  2339  Origem  Destino        64044         74563
# 96         369        450  2363  Origem  Destino        64044         74563
# 97         378        450  2408  Origem  Destino        64044         74563
# 98          26        447   942  Origem  Destino        64044         74563
# 99          30        447   976  Origem  Destino        64044         74563
#
# ...

# %%
df_trip450 = df_trip450[(df_trip450['repetições'] == df_trip450['repetições'].max()) & (df_trip450['grid_origem'] == 74155) & (df_trip450['grid_destino'] == 74563) &
                       (df_trip450['VehId_x_x'] == df_trip450['VehId_x_y'])]

df_trip450
# Out:
#     Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 52          59        450  1033  Origem  Destino        74155         74563
# 53          87        450  1176  Origem  Destino        74155         74563
# 54          94        450  1199  Origem  Destino        74155         74563
# 55         114        450  1274  Origem  Destino        74155         74563
# 56         133        450  1358  Origem  Destino        74155         74563
# 57         188        450  1559  Origem  Destino        74155         74563
# 58         190        450  1564  Origem  Destino        74155         74563
# 59         221        450  1697  Origem  Destino        74155         74563
# 60         245        450  1839  Origem  Destino        74155         74563
# 61         274        450  1950  Origem  Destino        74155         74563
# 62         308        450  2110  Origem  Destino        74155         74563
# ...

# %%
df_trip450['Trip'].unique()
# Out:
# array([1033, 1176, 1199, 1274, 1358, 1559, 1564, 1697, 1839, 1950, 2110,
#        2221, 2255])

# %% [markdown]
# ## Teste com o veículo 450 para o QGIS

# %%
import pandas as pd
import glob
import numpy as np
files = glob.glob("/media/joao/Seagate Expansion Drive 09032021/22122022/ved_descompactados/*.csv")

df = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df = pd.concat([plt,df], ignore_index=False)
    df = df.loc[(df['VehId'] == 450)]

df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 59942   373.672255    450  2548              0      42.292475      -83.682453
# 59943   373.672255    450  2548            600      42.292475      -83.682453
# 59944   373.672255    450  2548           1700      42.292475      -83.682453
# 59945   373.672255    450  2548           2000      42.292475      -83.682453
# 59946   373.672255    450  2548           2100      42.292475      -83.682453
# ...            ...    ...   ...            ...            ...             ...
# 317934  131.834911    450  1296         253900      42.296992      -83.681580
# 317935  131.834911    450  1296         255000      42.296992      -83.681580
# 317936  131.834911    450  1296         256000      42.296992      -83.681580
# 317937  131.834911    450  1296         257000      42.296968      -83.681218
# 317938  131.834911    450  1296         258100      42.296968      -83.681218
#
# ...

# %%
df = df.sort_values(by=['Trip','Timestamp(ms)'])


df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 46634     1.948142    450   771              0      42.287613      -83.686838
# 46635     1.948142    450   771           1100      42.287613      -83.686838
# 46636     1.948142    450   771           2000      42.287613      -83.686838
# 46637     1.948142    450   771           4200      42.287613      -83.686838
# 46638     1.948142    450   771           4500      42.287866      -83.687746
# ...            ...    ...   ...            ...            ...             ...
# 107240  374.733210    450  2553        1837500      42.297070      -83.681701
# 107241  374.733210    450  2553        1837600      42.297070      -83.681701
# 107242  374.733210    450  2553        1838100      42.296993      -83.681369
# 107243  374.733210    450  2553        1838600      42.296993      -83.681369
# 107244  374.733210    450  2553        1839600      42.296993      -83.681369
#
# ...

# %%
#df = df.sort_values(by='DayNum')

df['datetime'] = pd.to_datetime(df['DayNum'], unit='D', origin=pd.Timestamp('2017-11-01'))


print(df['datetime'].min())

print(df['datetime'].max())


print(df['DayNum'].min())

print(df['DayNum'].max())

print(df.shape)
# Out:
# 2017-11-02 22:45:19.495199744
# 2018-11-10 17:35:49.385558528
# 1.94814230555
# 374.733210481
# (362712, 23)

# %%
t = pd.DataFrame()

t = pd.date_range(start='2017-11-02 22:45:19.495199744', end='2018-11-10 17:35:49.385558528', periods=362712)


df['datetime'] = t

df.datetime
# Out:
# 46634    2017-11-02 22:45:19.495199744
# 46635    2017-11-02 22:46:48.294904992
# 46636    2017-11-02 22:48:17.094610240
# 46637    2017-11-02 22:49:45.894315489
# 46638    2017-11-02 22:51:14.694020737
#                       ...
# 107240   2018-11-10 17:29:54.186737536
# 107241   2018-11-10 17:31:22.986442784
# 107242   2018-11-10 17:32:51.786148032
# 107243   2018-11-10 17:34:20.585853280
# 107244   2018-11-10 17:35:49.385558528
# Name: datetime, Length: 362712, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df['datetime']).round('s')

df.datetime
# Out:
# 46634    2017-11-02 22:45:19
# 46635    2017-11-02 22:46:48
# 46636    2017-11-02 22:48:17
# 46637    2017-11-02 22:49:46
# 46638    2017-11-02 22:51:15
#                  ...
# 107240   2018-11-10 17:29:54
# 107241   2018-11-10 17:31:23
# 107242   2018-11-10 17:32:52
# 107243   2018-11-10 17:34:21
# 107244   2018-11-10 17:35:49
# Name: datetime, Length: 362712, dtype: datetime64[ns]

# %%
df.to_csv('veiculo450.csv')

# %% [markdown]
# ## Veículo 550: grids diferentes e o mesmo veículo

# %%
vei550 = res[res['VehId_x'] == 550]

vei550
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 332      550        64033         71591           8
# 333      550        64034         71591          13
# 334      550        64034         76704           6
# 335      550        64034         78354          12
# 336      550        71169         64033           7
# 337      550        71169         64034           5
# 338      550        71592         64033           5
# 339      550        74544         78354           5
# 340      550        74548         78354          11
# 341      550        74550         78354           6
# 342      550        77130         74556           6
# 343      550        77130         74557           5
# 344      550        78354         74545           5
# 345      550        78354         74547           7
# 346      550        78354         74550          20

# %%
df_trip550 = df_final.merge(vei550, how='inner', on=['grid_origem','grid_destino'])

df_trip550
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 0            19        415   836  Origem  Destino        64034         78354
# 1            65        311  2718  Origem  Destino        64034         78354
# 2             7         12   487  Origem  Destino        64034         78354
# 3            57         12   752  Origem  Destino        64034         78354
# 4           112         12  1027  Origem  Destino        64034         78354
# ..          ...        ...   ...     ...      ...          ...           ...
# 163         130        550  1885  Origem  Destino        64033         71591
# 164         141        550  1960  Origem  Destino        64033         71591
# 165         196        550  2318  Origem  Destino        64033         71591
# 166         227        550  2541  Origem  Destino        64033         71591
# 167         244        550  2675  Origem  Destino        64033         71591
#
# ...

# %%
df_trip550 = df_trip550[(df_trip550['repetições'] == df_trip550['repetições'].max()) & (df_trip550['grid_origem'] != df_trip550['grid_destino']) &
                       (df_trip550['VehId_x_x'] == df_trip550['VehId_x_y'])]

df_trip550
# Out:
#     Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 60          24        550   680  Origem  Destino        78354         74550
# 61          33        550   839  Origem  Destino        78354         74550
# 62          48        550  1125  Origem  Destino        78354         74550
# 63          97        550  1638  Origem  Destino        78354         74550
# 64         107        550  1718  Origem  Destino        78354         74550
# 65         124        550  1838  Origem  Destino        78354         74550
# 66         144        550  1977  Origem  Destino        78354         74550
# 67         146        550  1991  Origem  Destino        78354         74550
# 68         149        550  2009  Origem  Destino        78354         74550
# 69         159        550  2092  Origem  Destino        78354         74550
# 70         160        550  2099  Origem  Destino        78354         74550
# ...

# %%
df_trip550['Trip'].unique()
# Out:
# array([ 680,  839, 1125, 1638, 1718, 1838, 1977, 1991, 2009, 2092, 2099,
#        2215, 2300, 2338, 2424, 2452, 2456, 2795, 2872, 3030])

# %% [markdown]
# ## Teste com o veículo 550 para o QGIS

# %%
import pandas as pd
import glob
import numpy as np
files = glob.glob("/media/joao/Seagate Expansion Drive 09032021/22122022/ved_descompactados/*.csv")

df = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df = pd.concat([plt,df], ignore_index=False)
    df = df.loc[(df['VehId'] == 550)]

df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 37451   372.091519    550  3096              0      42.309324      -83.677293
# 37452   372.091519    550  3096            800      42.309324      -83.677293
# 37453   372.091519    550  3096           1800      42.309324      -83.677293
# 37454   372.091519    550  3096           2700      42.309324      -83.677293
# 37455   372.091519    550  3096           2800      42.309324      -83.677293
# ...            ...    ...   ...            ...            ...             ...
# 396518  133.724346    550  1535         204900      42.295215      -83.704060
# 396519  133.724346    550  1535         205300      42.295215      -83.704060
# 396520  133.724346    550  1535         206100      42.295215      -83.704060
# 396521  133.724346    550  1535         206300      42.295215      -83.704060
# 396522  133.724346    550  1535         207300      42.295215      -83.704060
#
# ...

# %%
df = df.sort_values(by=['Trip','Timestamp(ms)'])


df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 64987     1.002938    550   413              0      42.291749      -83.682617
# 64988     1.002938    550   413            300      42.291749      -83.682617
# 64989     1.002938    550   413           1400      42.291749      -83.682617
# 64990     1.002938    550   413           2400      42.291749      -83.682617
# 64991     1.002938    550   413           3500      42.291749      -83.682617
# ...            ...    ...   ...            ...            ...             ...
# 110207  374.542273    550  3115         193700      42.295235      -83.704289
# 110208  374.542273    550  3115         194200      42.295279      -83.704552
# 110209  374.542273    550  3115         194800      42.295279      -83.704552
# 110210  374.542273    550  3115         195900      42.295279      -83.704552
# 110211  374.542273    550  3115         197000      42.295279      -83.704552
#
# ...

# %%
#df = df.sort_values(by='DayNum')

df['datetime'] = pd.to_datetime(df['DayNum'], unit='D', origin=pd.Timestamp('2017-11-01'))


print(df['datetime'].min())

print(df['datetime'].max())


print(df['DayNum'].min())

print(df['DayNum'].max())

print(df.shape)
# Out:
# 2017-11-02 00:04:13.838400512
# 2018-11-10 13:00:52.427203328
# 1.00293794445
# 374.542273463
# (95833, 23)

# %%
t = pd.DataFrame()

t = pd.date_range(start='2017-11-02 00:04:13.838400512', end='2018-11-10 13:00:52.427203328', periods=95833)


df['datetime'] = t

df.datetime
# Out:
# 64987    2017-11-02 00:04:13.838400512
# 64988    2017-11-02 00:09:50.613158304
# 64989    2017-11-02 00:15:27.387916097
# 64990    2017-11-02 00:21:04.162673890
# 64991    2017-11-02 00:26:40.937431683
#                       ...
# 110207   2018-11-10 12:38:25.328172156
# 110208   2018-11-10 12:44:02.102929948
# 110209   2018-11-10 12:49:38.877687740
# 110210   2018-11-10 12:55:15.652445532
# 110211   2018-11-10 13:00:52.427203328
# Name: datetime, Length: 95833, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df['datetime']).round('s')

df.datetime
# Out:
# 64987    2017-11-02 00:04:14
# 64988    2017-11-02 00:09:51
# 64989    2017-11-02 00:15:27
# 64990    2017-11-02 00:21:04
# 64991    2017-11-02 00:26:41
#                  ...
# 110207   2018-11-10 12:38:25
# 110208   2018-11-10 12:44:02
# 110209   2018-11-10 12:49:39
# 110210   2018-11-10 12:55:16
# 110211   2018-11-10 13:00:52
# Name: datetime, Length: 95833, dtype: datetime64[ns]

# %%
df.to_csv('veiculo550.csv')

# %% [markdown]
# ## Veículo 560: grids diferentes e o mesmo veículo

# %%
vei560 = res[res['VehId_x'] == 560]

vei560
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 350      560        45825         78354           6
# 351      560        78354         44602           6
# 352      560        78354         45009           6
# 353      560        78354         45012           9
# 354      560        78354         45013           9
# 355      560        78354         45422           6
# 356      560        78354         47466          14
# 357      560        78354         77480           6
# 358      560        78354         77896           8
# 359      560        78354         77928          36
# 360      560        78354         78321           6
# 361      560        78354         78354          91

# %%
vei560 = vei560.drop(vei560[vei560['repetições'] == 91].index)

vei560
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 350      560        45825         78354           6
# 351      560        78354         44602           6
# 352      560        78354         45009           6
# 353      560        78354         45012           9
# 354      560        78354         45013           9
# 355      560        78354         45422           6
# 356      560        78354         47466          14
# 357      560        78354         77480           6
# 358      560        78354         77896           8
# 359      560        78354         77928          36
# 360      560        78354         78321           6

# %%
df_trip560 = df_final.merge(vei560, how='inner', on=['grid_origem','grid_destino'])

df_trip560
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 0            54        311  2492  Origem  Destino        78354         77896
# 1            34        203   937  Origem  Destino        78354         77896
# 2            41        560   117  Origem  Destino        78354         77896
# 3           204        560   745  Origem  Destino        78354         77896
# 4           255        560  1007  Origem  Destino        78354         77896
# ..          ...        ...   ...     ...      ...          ...           ...
# 134         206        560   750  Origem  Destino        45825         78354
# 135         214        560   786  Origem  Destino        45825         78354
# 136         219        560   818  Origem  Destino        45825         78354
# 137         309        560  1291  Origem  Destino        45825         78354
# 138         365        560  1573  Origem  Destino        45825         78354
#
# ...

# %%
df_trip560 = df_trip560[(df_trip560['repetições'] == df_trip560['repetições'].max()) & (df_trip560['grid_origem'] != df_trip560['grid_destino']) &
                       (df_trip560['VehId_x_x'] == df_trip560['VehId_x_y'])]

df_trip560
# Out:
#     Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 25           7        560    14  Origem  Destino        78354         77928
# 26          16        560    58  Origem  Destino        78354         77928
# 27          28        560    85  Origem  Destino        78354         77928
# 28          36        560   110  Origem  Destino        78354         77928
# 29          40        560   116  Origem  Destino        78354         77928
# 30          47        560   135  Origem  Destino        78354         77928
# 31          65        560   190  Origem  Destino        78354         77928
# 32          70        560   199  Origem  Destino        78354         77928
# 33          89        560   263  Origem  Destino        78354         77928
# 34          97        560   304  Origem  Destino        78354         77928
# 35          98        560   305  Origem  Destino        78354         77928
# ...

# %%
df_trip560['Trip'].unique()
# Out:
# array([  14,   58,   85,  110,  116,  135,  190,  199,  263,  304,  305,
#         310,  356,  368,  455,  456,  460,  601,  606,  616,  660,  727,
#         776,  815,  835,  855,  952,  970,  997, 1043, 1074, 1093, 1098,
#        1116, 1635, 1659])

# %% [markdown]
# ## Teste com o veículo 560 para o QGIS

# %%
import pandas as pd
import glob
import numpy as np
files = glob.glob("/media/joao/Seagate Expansion Drive 09032021/22122022/ved_descompactados/*.csv")

df = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df = pd.concat([plt,df], ignore_index=False)
    df = df.loc[(df['VehId'] == 560)]

df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 83055   373.556549    560  1676              0      42.274480      -83.674061
# 83056   373.556549    560  1676            800      42.274480      -83.674061
# 83057   373.556549    560  1676           1900      42.274480      -83.674061
# 83058   373.556549    560  1676           2400      42.274480      -83.674061
# 83059   373.556549    560  1676           2900      42.274480      -83.674061
# ...            ...    ...   ...            ...            ...             ...
# 271727  130.563069    560   448         767400      42.280702      -83.746001
# 271728  130.563069    560   448         767700      42.280702      -83.746001
# 271729  130.563069    560   448         767800      42.280702      -83.746001
# 271730  130.563069    560   448         768700      42.280702      -83.746001
# 271731  130.563069    560   448         768800      42.280702      -83.746001
#
# ...

# %%
df = df.sort_values(by=['Trip','Timestamp(ms)'])


df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 131100    2.623466    560     2              0      42.252974      -83.674152
# 131101    2.623466    560     2           1000      42.252974      -83.674152
# 131102    2.623466    560     2           1100      42.252974      -83.674152
# 131103    2.623466    560     2           1800      42.252974      -83.674152
# 131104    2.623466    560     2           2000      42.252974      -83.674152
# ...            ...    ...   ...            ...            ...             ...
# 86278   373.556549    560  1676        1856400      42.274291      -83.674524
# 86279   373.556549    560  1676        1857200      42.274291      -83.674524
# 86280   373.556549    560  1676        1857500      42.274291      -83.674524
# 86281   373.556549    560  1676        1858200      42.274291      -83.674524
# 86282   373.556549    560  1676        1858500      42.274291      -83.674524
#
# ...

# %%
#df = df.sort_values(by='DayNum')

df['datetime'] = pd.to_datetime(df['DayNum'], unit='D', origin=pd.Timestamp('2017-11-01'))


print(df['datetime'].min())

print(df['datetime'].max())


print(df['DayNum'].min())

print(df['DayNum'].max())

print(df.shape)
# Out:
# 2017-11-03 14:57:47.424000256
# 2018-11-09 13:21:25.822368
# 2.62346555556
# 373.55654887
# (887056, 23)

# %%
t = pd.DataFrame()

t = pd.date_range(start='2017-11-03 14:57:47.424000256', end='2018-11-09 13:21:25.822368', periods=887056)


df['datetime'] = t

df.datetime
# Out:
# 131100   2017-11-03 14:57:47.424000256
# 131101   2017-11-03 14:58:23.553235081
# 131102   2017-11-03 14:58:59.682469907
# 131103   2017-11-03 14:59:35.811704733
# 131104   2017-11-03 15:00:11.940939559
#                       ...
# 86278    2018-11-09 13:19:01.305428700
# 86279    2018-11-09 13:19:37.434663524
# 86280    2018-11-09 13:20:13.563898352
# 86281    2018-11-09 13:20:49.693133176
# 86282    2018-11-09 13:21:25.822368000
# Name: datetime, Length: 887056, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df['datetime']).round('s')

df.datetime
# Out:
# 131100   2017-11-03 14:57:47
# 131101   2017-11-03 14:58:24
# 131102   2017-11-03 14:59:00
# 131103   2017-11-03 14:59:36
# 131104   2017-11-03 15:00:12
#                  ...
# 86278    2018-11-09 13:19:01
# 86279    2018-11-09 13:19:37
# 86280    2018-11-09 13:20:14
# 86281    2018-11-09 13:20:50
# 86282    2018-11-09 13:21:26
# Name: datetime, Length: 887056, dtype: datetime64[ns]

# %%
df.to_csv('veiculo560.csv')

# %% [markdown]
# ## Veículo 561: grids diferentes e o mesmo veículo

# %%
vei561 = res[res['VehId_x'] == 561]

vei561
# Out:
#      VehId_x  grid_origem  grid_destino  repetições
# 362      561        21933         28551           8
# 363      561        47449         48204           8
# 364      561        47451         48204          11
# 365      561        47451         48205           6
# 366      561        47868         48204          15
# 367      561        47868         48205           5
# 368      561        47869         48204           5
# 369      561        48204         48284           5
# 370      561        66449         50738          44
# 371      561        66449         51147           9
# 372      561        66449         51558          11

# %%
df_trip561 = df_final.merge(vei561, how='inner', on=['grid_origem','grid_destino'])

df_trip561
# Out:
#      Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 0            42        392   706  Origem  Destino        47449         48204
# 1            37        561   729  Origem  Destino        47449         48204
# 2            68        561   907  Origem  Destino        47449         48204
# 3           108        561  1199  Origem  Destino        47449         48204
# 4           138        561  1403  Origem  Destino        47449         48204
# ..          ...        ...   ...     ...      ...          ...           ...
# 132         226        561  2026  Origem  Destino        21933         28551
# 133         231        561  2109  Origem  Destino        21933         28551
# 134         261        561  2374  Origem  Destino        21933         28551
# 135         302        561  2734  Origem  Destino        21933         28551
# 136         314        561  2808  Origem  Destino        21933         28551
#
# ...

# %%
df_trip561 = df_trip561[(df_trip561['repetições'] == df_trip561['repetições'].max()) & (df_trip561['grid_origem'] != df_trip561['grid_destino']) &
                       (df_trip561['VehId_x_x'] == df_trip561['VehId_x_y'])]

df_trip561
# Out:
#     Unnamed: 0  VehId_x_x  Trip Origens Destinos  grid_origem  grid_destino  \
# 25          14        561   573  Origem  Destino        66449         50738
# 26          23        561   633  Origem  Destino        66449         50738
# 27          24        561   642  Origem  Destino        66449         50738
# 28          26        561   650  Origem  Destino        66449         50738
# 29          28        561   661  Origem  Destino        66449         50738
# 30          34        561   705  Origem  Destino        66449         50738
# 31          46        561   803  Origem  Destino        66449         50738
# 32          65        561   893  Origem  Destino        66449         50738
# 33          66        561   900  Origem  Destino        66449         50738
# 34          71        561   938  Origem  Destino        66449         50738
# 35          81        561  1011  Origem  Destino        66449         50738
# ...

# %%
df_trip561['Trip'].unique()
# Out:
# array([ 573,  633,  642,  650,  661,  705,  803,  893,  900,  938, 1011,
#        1047, 1090, 1092, 1158, 1258, 1377, 1400, 1425, 1433, 1447, 1505,
#        1599, 1639, 1655, 1752, 1796, 1812, 1821, 1832, 1941, 1946, 1996,
#        2019, 2371, 2518, 2538, 2606, 2628, 2670, 2677, 2764, 2777, 2871])

# %% [markdown]
# ## Teste com o veículo 561 para o QGIS

# %%
import pandas as pd
import glob
import numpy as np
files = glob.glob("/media/joao/Seagate Expansion Drive 09032021/22122022/ved_descompactados/*.csv")

df = pd.DataFrame()
for f in files:
    plt = pd.read_csv(f, sep = ",")
    df = pd.concat([plt,df], ignore_index=False)
    df = df.loc[(df['VehId'] == 561)]

df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 37900   372.736791    561  2889              0      42.243244      -83.749036
# 37901   372.736791    561  2889            800      42.243244      -83.749036
# 37902   372.736791    561  2889           1000      42.243244      -83.749036
# 37903   372.736791    561  2889           1400      42.243244      -83.749036
# 37904   372.736791    561  2889           1500      42.243244      -83.749036
# ...            ...    ...   ...            ...            ...             ...
# 371176  132.728936    561  1230         249100      42.272229      -83.799133
# 371177  132.728936    561  1230         250100      42.272229      -83.799133
# 371178  132.728936    561  1230         251200      42.272229      -83.799133
# 371179  132.728936    561  1230         252100      42.272229      -83.799133
# 371180  132.728936    561  1230         252200      42.272229      -83.799133
#
# ...

# %%
df = df.sort_values(by=['Trip','Timestamp(ms)'])


df
# Out:
#             DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 293386    4.761068    561   304              0      42.228227      -83.797865
# 293387    4.761068    561   304           1100      42.228227      -83.797865
# 293388    4.761068    561   304           2100      42.228227      -83.797865
# 293389    4.761068    561   304           3100      42.228227      -83.797865
# 293390    4.761068    561   304           3400      42.228227      -83.797865
# ...            ...    ...   ...            ...            ...             ...
# 38575   372.736791    561  2889         450000      42.229440      -83.739202
# 38576   372.736791    561  2889         450300      42.229440      -83.739202
# 38577   372.736791    561  2889         450800      42.229440      -83.739202
# 38578   372.736791    561  2889         451300      42.229440      -83.739202
# 38579   372.736791    561  2889         452000      42.229440      -83.739202
#
# ...

# %%
#df = df.sort_values(by='DayNum')

df['datetime'] = pd.to_datetime(df['DayNum'], unit='D', origin=pd.Timestamp('2017-11-01'))


print(df['datetime'].min())

print(df['datetime'].max())


print(df['DayNum'].min())

print(df['DayNum'].max())

print(df.shape)
# Out:
# 2017-11-05 18:15:56.259999744
# 2018-11-08 17:40:58.771171328
# 4.76106782407
# 372.736791333
# (270330, 23)

# %%
t = pd.DataFrame()

t = pd.date_range(start='2017-11-05 18:15:56.259999744', end='2018-11-08 17:40:58.771171328', periods=270330)


df['datetime'] = t

df.datetime
# Out:
# 293386   2017-11-05 18:15:56.259999744
# 293387   2017-11-05 18:17:53.868922616
# 293388   2017-11-05 18:19:51.477845488
# 293389   2017-11-05 18:21:49.086768361
# 293390   2017-11-05 18:23:46.695691233
#                       ...
# 38575    2018-11-08 17:33:08.335479836
# 38576    2018-11-08 17:35:05.944402708
# 38577    2018-11-08 17:37:03.553325580
# 38578    2018-11-08 17:39:01.162248456
# 38579    2018-11-08 17:40:58.771171328
# Name: datetime, Length: 270330, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df['datetime']).round('s')

df.datetime
# Out:
# 293386   2017-11-05 18:15:56
# 293387   2017-11-05 18:17:54
# 293388   2017-11-05 18:19:51
# 293389   2017-11-05 18:21:49
# 293390   2017-11-05 18:23:47
#                  ...
# 38575    2018-11-08 17:33:08
# 38576    2018-11-08 17:35:06
# 38577    2018-11-08 17:37:04
# 38578    2018-11-08 17:39:01
# 38579    2018-11-08 17:40:59
# Name: datetime, Length: 270330, dtype: datetime64[ns]

# %%
df.to_csv('veiculo561.csv')
